# %%
from sklearn.datasets import make_regression

# %%
X, Y = make_regression(n_informative=5, random_state=32)

# %%
X.shape
# Out:
# (100, 100)

# %%
from sklearn.decomposition import PCA

# %%
model = PCA()

# %%
model.fit(X)
# Out:
# PCA()

# %%
model.transform(X)
# Out:
# array([[-2.96212219e+00,  1.35743046e+00, -1.91111595e+00, ...,
#         -1.81490684e-02, -1.34175930e-03,  1.99840144e-15],
#        [-7.05321515e-01, -1.14535444e+00,  2.92674861e+00, ...,
#         -3.87120206e-04,  4.64871744e-03,  4.57966998e-16],
#        [-8.20742100e-01, -9.47745132e-01, -2.97604337e+00, ...,
#         -2.45366310e-02, -3.35110986e-03,  5.82867088e-16],
#        ...,
#        [-1.10109673e+00, -4.57442003e-01, -1.56079126e+00, ...,
#          1.78454666e-03, -1.11160750e-02, -5.41233725e-16],
#        [-2.35527305e-02,  1.40054844e+00, -4.42557408e+00, ...,
#         -3.44605170e-02, -7.63668359e-03, -1.94289029e-16],
#        [ 4.81722085e-01, -7.68489310e-01, -2.42075177e+00, ...,
#          4.35795892e-03,  4.32910856e-03, -1.27675648e-15]])

# %%
model.explained_variance_ratio_ * 100
# Out:
# array([3.62144581e+00, 3.55070420e+00, 3.49335220e+00, 3.30555239e+00,
#        3.11926960e+00, 2.96466536e+00, 2.83494179e+00, 2.80168417e+00,
#        2.64816044e+00, 2.62605233e+00, 2.55017215e+00, 2.46963353e+00,
#        2.44068606e+00, 2.38217647e+00, 2.33426432e+00, 2.22335954e+00,
#        2.17213335e+00, 2.08198953e+00, 2.04805953e+00, 1.98807464e+00,
#        1.92051074e+00, 1.80869398e+00, 1.79716843e+00, 1.74169195e+00,
#        1.67016408e+00, 1.62223889e+00, 1.56133340e+00, 1.46949985e+00,
#        1.43496853e+00, 1.40827361e+00, 1.33994247e+00, 1.26374519e+00,
#        1.24815399e+00, 1.22936304e+00, 1.16804921e+00, 1.13365710e+00,
#        1.10743885e+00, 1.05030977e+00, 1.02805641e+00, 9.91315243e-01,
#        8.98688754e-01, 8.83671600e-01, 8.69920342e-01, 8.08950790e-01,
#        7.80021993e-01, 7.63577218e-01, 7.39741072e-01, 6.83271112e-01,
#        6.65783213e-01, 6.58951332e-01, 6.36627747e-01, 6.22221179e-01,
# ...

# %%
import numpy as np

# %%
len(np.array([3.62144581e+00, 3.55070420e+00, 3.49335220e+00, 3.30555239e+00,
       3.11926960e+00, 2.96466536e+00, 2.83494179e+00, 2.80168417e+00,
       2.64816044e+00, 2.62605233e+00, 2.55017215e+00, 2.46963353e+00,
       2.44068606e+00, 2.38217647e+00, 2.33426432e+00, 2.22335954e+00,
       2.17213335e+00, 2.08198953e+00, 2.04805953e+00, 1.98807464e+00,
       1.92051074e+00, 1.80869398e+00, 1.79716843e+00, 1.74169195e+00,
       1.67016408e+00, 1.62223889e+00, 1.56133340e+00, 1.46949985e+00,
       1.43496853e+00, 1.40827361e+00, 1.33994247e+00, 1.26374519e+00,
       1.24815399e+00, 1.22936304e+00, 1.16804921e+00, 1.13365710e+00,
       1.10743885e+00, 1.05030977e+00, 1.02805641e+00]))
# Out:
# 39

# %%
model2 = PCA(n_components=30)

# %%
model2.fit(X)
# Out:
# PCA(n_components=30)

# %%
newX = model2.transform(X)

# %% [markdown]
# # **Regression**

# %%
from sklearn.linear_model import LinearRegression

# %%
mdln = LinearRegression()
mdln.fit(newX, Y)
# Out:
# LinearRegression()
