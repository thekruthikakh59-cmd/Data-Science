# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('/content/cluster (2).xlsx')

# %%
X = df.values

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score

# %%
model = DBSCAN(eps = 0.5, min_samples = 4)
model.fit(X)
# Out:
# DBSCAN(min_samples=4)

# %%
silhouette_score(X, model.labels_)
# Out:
# np.float64(0.0003403561440920483)

# %%
min_samples_ls = [3, 4, 5]
eps_ls = [1.5, 2, 2.5]

# %%
for min_samples in min_samples_ls:
    for eps in eps_ls:
        # print(min_samples, eps)
        model = DBSCAN(eps = eps, min_samples = min_samples)
        model.fit(X)
        print(min_samples, eps, "===>", silhouette_score(X, model.labels_))
# Out:
# 3 1.5 ===> 0.2655040579484137
# 3 2 ===> 0.31244194549306736
# 3 2.5 ===> 0.26437380622674983
# 4 1.5 ===> 0.2287281411145403
# 4 2 ===> 0.30265391578065726
# 4 2.5 ===> 0.26437380622674983
# 5 1.5 ===> 0.027215745576324068
# 5 2 ===> 0.3156097095891804
# 5 2.5 ===> 0.26437380622674983

# %%
mod = DBSCAN(min_samples=5, eps=2)
mod.fit(X)
mod.labels_
# Out:
# array([ 5,  2,  0,  1,  1,  1,  1,  1,  2,  2,  2,  0,  1,  1,  2,  2,  0,
#         2,  3,  2,  2,  0,  2,  2,  0,  2,  1,  2,  0,  1, -1,  2,  5,  2,
#         2,  2,  0,  5,  3,  1,  1,  0,  2,  0,  4,  2,  1,  2,  0,  5,  0,
#         0,  3,  2,  1,  2,  0,  2,  2,  3,  3,  3,  3,  0,  2,  1,  2,  2,
#         2,  4,  2,  3,  2,  1,  2,  4,  0,  0,  2,  0,  4,  3,  2,  4,  3,
#         2,  2,  3,  2,  1,  3, -1,  0, -1,  3,  2,  3,  1,  5,  1])

# %%
plt.scatter(X[:, 0], X[:, 1], c=mod.labels_)

# %% [markdown]
# # **For streamlit**

# %%
# import streamlit as st
fig, ax = plt.subplots()
ax.scatter(X[:, 0], X[:, 1], c=mod.labels_)
# st.pyplot(fig)
