# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs

# %%
X,t = make_blobs(centers=5, cluster_std=1.5)

# %%
X = X.round(2)

# %%
df = pd.DataFrame(X, columns=['X', 'y'])

# %%
plt.scatter(df['X'],df['y'])

# %%
df.to_excel("blobdata.xlsx")

# %%
df = pd.read_excel("blobdata.xlsx", index_col="Unnamed: 0")

# %%
plt.scatter(df['X'], df['y'])

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
mdtree = DecisionTreeRegressor(max_depth=4)

# %%
mdtree.fit(df[['X']], df['y'])
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
yp = mdtree.predict(df[['X']])

# %%
# yp

# %%
plt.scatter(df['X'], df['y'])
plt.scatter(df['X'], yp, color='red')
#

# %%
df
# Out:
#        X      y
# 0  -7.40  -4.37
# 1  -0.13  -6.31
# 2  -3.31   1.64
# 3   6.16  -8.35
# 4   4.24 -10.07
# ..   ...    ...
# 95  9.50  -8.48
# 96  5.53  -7.98
# 97 -8.88  -5.65
# 98 -2.80   3.25
# 99 -0.37  -0.98
#
# [100 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
# train_test_split(df, random_state=0)

# %%
X = df[['X']].values
y = df['y'].values

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, random_state=0)

# %%
xtrain.shape
# Out:
# (75, 2)

# %%
from sklearn.metrics import mean_squared_error

# %%
model1 = DecisionTreeRegressor(max_depth=1)
model1.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
yptrain1 = model1.predict(xtrain)
mean_squared_error(ytrain, yptrain1)
# Out:
# 13.18567988888889

# %%
yptest1 = model1.predict(xtest)
mean_squared_error(ytest, yptest1)
# Out:
# 18.771131825617285

# %%
model2 = DecisionTreeRegressor(max_depth=2)
model2.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
yptrain2 = model2.predict(xtrain)
mean_squared_error(ytrain, yptrain2)
# Out:
# 11.515748242424241

# %%
yptest2 = model2.predict(xtest)
mean_squared_error(ytest, yptest2)
# Out:
# 15.772362323589425

# %%
model3 = DecisionTreeRegressor(max_depth=3)
model3.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
yptrain3 = model3.predict(xtrain)
mean_squared_error(ytrain, yptrain3)
# Out:
# 9.149942219047619

# %%
yptest3 = model3.predict(xtest)
mean_squared_error(ytest, yptest3)
# Out:
# 18.747469448367347

# %%
model4 = DecisionTreeRegressor(max_depth=4)
model4.fit(xtrain, ytrain)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
yptrain4 = model4.predict(xtrain)
mean_squared_error(ytrain, yptrain3)
# Out:
# 9.149942219047619

# %%
yptest4 = model4.predict(xtest)
mean_squared_error(ytest, yptest3)
# Out:
# 18.747469448367347
